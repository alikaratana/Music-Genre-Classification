# %% [markdown]
# ### MULTICLASS CLASSIFICATION FOR METAL, CLASSICAL, BLUES, HIPHOP AND POP MUSIC GENRES

# %% [markdown]
# * First of all, let's import every library and our config.py and functions.py files to the notebook.

# %%
# %matplotlib inline
import itertools
import numpy, scipy, matplotlib.pyplot as plt, pandas, librosa,sklearn
import config, functions

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %% [markdown]
# * We obtain the data only for Metal, Classical, Blues, Hiphop and Pop music from our dataset.

# %%
data_set=pandas.read_csv('data_set.csv',index_col=False)
data_set=pandas.concat((data_set[600:700],data_set[100:200],data_set[400:500],data_set[0:100],data_set[700:800]),
                       ignore_index=True)
GENRES=config.Genre5.GENRE_NAMES

number_of_rows,number_of_cols = data_set.shape
data_set[:5].style
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_a0c456ac_ca99_11e6_a06b_240a6438217e" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   meanZCR
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   stdZCR
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   meanSpecCentroid
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   stdSpecCentroid
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   meanSpecContrast
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   stdSpecContrast
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   meanSpecBandwidth
#
#
#
#                 <th class="col_heading level0 col7" colspan=1>
#                   stdSpecBandwidth
#
#
#
#                 <th class="col_heading level0 col8" colspan=1>
#                   meanSpecRollof
#
#
#
#                 <th class="col_heading level0 col9" colspan=1>
#                   stdSpecRollof
#
#
#
#                 <th class="col_heading level0 col10" colspan=1>
#                   meanMFCC_1
#
#
#
#                 <th class="col_heading level0 col11" colspan=1>
#                   stdMFCC_1
#
#
#
#                 <th class="col_heading level0 col12" colspan=1>
#                   meanMFCC_2
#
#
#
#                 <th class="col_heading level0 col13" colspan=1>
#                   stdMFCC_2
#
#
#
#                 <th class="col_heading level0 col14" colspan=1>
#                   meanMFCC_3
#
#
#
#                 <th class="col_heading level0 col15" colspan=1>
#                   stdMFCC_3
#
#
#
#                 <th class="col_heading level0 col16" colspan=1>
#                   meanMFCC_4
#
#
#
#                 <th class="col_heading level0 col17" colspan=1>
#                   stdMFCC_4
#
#
#
#                 <th class="col_heading level0 col18" colspan=1>
#                   meanMFCC_5
#
#
#
#                 <th class="col_heading level0 col19" colspan=1>
#                   stdMFCC_5
#
#
#
#                 <th class="col_heading level0 col20" colspan=1>
#                   meanMFCC_6
#
#
#
#                 <th class="col_heading level0 col21" colspan=1>
#                   stdMFCC_6
#
#
#
#                 <th class="col_heading level0 col22" colspan=1>
#                   meanMFCC_7
#
#
#
#                 <th class="col_heading level0 col23" colspan=1>
#                   stdMFCC_7
#
#
#
#                 <th class="col_heading level0 col24" colspan=1>
#                   meanMFCC_8
#
#
#
#                 <th class="col_heading level0 col25" colspan=1>
#                   stdMFCC_8
#
#
#
#                 <th class="col_heading level0 col26" colspan=1>
#                   meanMFCC_9
#
#
#
#                 <th class="col_heading level0 col27" colspan=1>
#                   stdMFCC_9
#
#
#
#                 <th class="col_heading level0 col28" colspan=1>
#                   meanMFCC_10
#
#
#
#                 <th class="col_heading level0 col29" colspan=1>
#                   stdMFCC_10
#
#
#
#                 <th class="col_heading level0 col30" colspan=1>
#                   meanMFCC_11
#
#
#
#                 <th class="col_heading level0 col31" colspan=1>
#                   stdMFCC_11
#
#
#
#                 <th class="col_heading level0 col32" colspan=1>
#                   meanMFCC_12
#
#
#
#                 <th class="col_heading level0 col33" colspan=1>
#                   stdMFCC_12
#
#
#
#                 <th class="col_heading level0 col34" colspan=1>
#                   meanMFCC_13
#
#
#
#                 <th class="col_heading level0 col35" colspan=1>
#                   stdMFCC_13
#
#
#
#                 <th class="col_heading level0 col36" colspan=1>
#                   Genre
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a0c456ac_ca99_11e6_a06b_240a6438217e"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col0"
#                  class="data row0 col0" >
#                     0.290531
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col1"
#                  class="data row0 col1" >
#                     -0.630537
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col2"
#                  class="data row0 col2" >
#                     0.356024
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col3"
#                  class="data row0 col3" >
#                     -0.621638
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col4"
#                  class="data row0 col4" >
#                     -0.24305
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col5"
#                  class="data row0 col5" >
#                     0.0522054
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col6"
#                  class="data row0 col6" >
#                     0.206591
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col7"
#                  class="data row0 col7" >
#                     -0.489576
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col8"
#                  class="data row0 col8" >
#                     0.301021
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6438217erow0_col9"
#                  class="data row0 col9" >
#                     -0.306651
#
#
#
#                 <td id="T_a0c456ac_ca99_11e6_a06b_240a6

# %% [markdown]
# * Let's split our dataset, %70 for training and %30 for test.
# * Then we seperate both train and test datasets into two part. One for feature columns, one for class column.

# %%
from sklearn.model_selection import train_test_split

data_set_values=numpy.array(data_set)

train, test = train_test_split(data_set_values, test_size = config.Genre5.TEST_SIZE,random_state=2,
                              stratify=data_set_values[:,number_of_cols-1])

train_x=train[:,:number_of_cols-1]
train_y=train[:,number_of_cols-1]

test_x=test[:,:number_of_cols-1]
test_y=test[:,number_of_cols-1]

print("Training data size: {}".format(train.shape))
print("Test data size: {}".format(test.shape))
# Out:
# Training data size: (350, 37)
# Test data size: (150, 37)

# %% [markdown]
# * We use several machine learning algorithms to make classification.
#  - **Algorithms used:**
#    - K-Neares Neighbor
#    - Random Forest
#    - Support Vector Machine
#    - Neural Network

# %% [markdown]
# * Application of KNN algorithm and its performance analysis

# %%
results_knn=[]
for i in range(1,11):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x,train_y)
    results_knn.append(knn.score(test_x,test_y))
    
max_accuracy_knn=max(results_knn)
best_k=1+results_knn.index(max(results_knn))
print("Max Accuracy is {:.3f} on test dataset with {} neighbors.\n".format(max_accuracy_knn,best_k))

plt.plot(numpy.arange(1,11),results_knn)
plt.xlabel("n Neighbors")
plt.ylabel("Accuracy")


knn=KNeighborsClassifier(n_neighbors=best_k)
knn.fit(train_x,train_y)
print("Training Score: {:.3f}".format(knn.score(train_x,train_y)))
print("Test score: {:.3f}".format(knn.score(test_x,test_y)))  

functions.plot_cnf(knn,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.853 on test dataset with 3 neighbors.
#
# Training Score: 0.923
# Test score: 0.853
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['H' 'H' 'P' 'M' 'M' 'M' 'Cl' 'B' 'P' 'B' 'P' 'H' 'Cl' 'H' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'H' 'P' 'M' 'M' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'M' 'B' 'P' 'P' 'M' 'Cl' 'H' 'B' 'P' 'Cl' 'H' 'P' 'P' 'B' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'H' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H'
#  'H' 'M' 'P' 'P' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B'
#  'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'H' 'M' 'M' 'Cl' 'P' 'P' 'B' 'H' 'M' 'M' 'Cl'
#  'M' 'B' 'M' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'P' 'H' 'P' 'B' 'Cl' 'M' 'H' 'M'
#  'B' 'H' 'Cl' 'P' 'B' 'H' 'P' 'H' 'B' 'H']
#
# Predicted Test dataset labels:
# ['H' 'H' 'P' 'H' 'H' 'M' 'Cl' 'B' 'P' 'B' 'P' 'P' 'Cl' 'P' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'H' 'Cl' 'Cl' 'M' 'H' 'H' 'H' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'P' 'H' 'H' 'B' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'H' 'H' 'P' 'P' 'M' 'Cl' 'H' 'B' 'P' 'Cl' 'H' 'P' 'P' 'B' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'H' 'Cl' 'H' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P'
#  'H' 'H' 'M' 'P' 'H' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M'
#  'B' 'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'M' 'M' 'H' 'Cl' 'P' 'H' 'B' 'H' 'M' 'M'
#  'Cl' 'M' 'B' 'H' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'H' 'Cl' 'P' 'B' 'Cl' 'M' 'H'
#  'M' 'B' 'H' 'Cl' 'P' 'B' 'H' 'H' 'H' 'B' 'H']

# %% [markdown]
# * Application of Random Forest algorithm and its performance analysis

# %%
results_forest=[]
for i in range(2,20):
    forest=RandomForestClassifier(random_state=42,n_estimators=i)
    forest.fit(train_x,train_y)
    results_forest.append(forest.score(test_x,test_y))
    
max_accuracy_forest=max(results_forest)
best_n_est=2+results_forest.index(max(results_forest))
print("Max Accuracy is {:.3f} on test dataset with {} estimators.\n".format(max_accuracy_forest,best_n_est))

plt.plot(numpy.arange(2,20),results_forest)
plt.xlabel("n Estimators")
plt.ylabel("Accuracy")


forest=RandomForestClassifier(random_state=42,n_estimators=best_n_est)
forest.fit(train_x,train_y)
print("Training Score: {:.3f}".format(forest.score(train_x,train_y)))
print("Test score: {:.3f}".format(forest.score(test_x,test_y)))

functions.plot_cnf(forest,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.907 on test dataset with 12 estimators.
#
# Training Score: 1.000
# Test score: 0.907
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['H' 'H' 'P' 'M' 'M' 'M' 'Cl' 'B' 'P' 'B' 'P' 'H' 'Cl' 'H' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'H' 'P' 'M' 'M' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'M' 'B' 'P' 'P' 'M' 'Cl' 'H' 'B' 'P' 'Cl' 'H' 'P' 'P' 'B' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'H' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H'
#  'H' 'M' 'P' 'P' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B'
#  'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'H' 'M' 'M' 'Cl' 'P' 'P' 'B' 'H' 'M' 'M' 'Cl'
#  'M' 'B' 'M' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'P' 'H' 'P' 'B' 'Cl' 'M' 'H' 'M'
#  'B' 'H' 'Cl' 'P' 'B' 'H' 'P' 'H' 'B' 'H']
#
# Predicted Test dataset labels:
# ['H' 'H' 'P' 'H' 'M' 'M' 'Cl' 'B' 'P' 'B' 'P' 'P' 'Cl' 'P' 'M' 'H' 'Cl' 'B'
#  'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'Cl' 'M' 'B' 'H' 'B' 'P' 'Cl' 'B'
#  'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'H' 'P' 'H' 'B' 'Cl' 'H' 'Cl' 'H' 'Cl' 'H'
#  'H' 'H' 'P' 'P' 'M' 'Cl' 'P' 'B' 'P' 'Cl' 'H' 'P' 'P' 'B' 'M' 'B' 'B' 'P'
#  'P' 'P' 'Cl' 'Cl' 'B' 'H' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H' 'H'
#  'M' 'H' 'H' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B' 'P'
#  'M' 'Cl' 'P' 'M' 'M' 'H' 'H' 'M' 'M' 'Cl' 'P' 'P' 'B' 'P' 'M' 'M' 'Cl' 'M'
#  'B' 'M' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'H' 'H' 'P' 'B' 'Cl' 'M' 'H' 'M' 'B'
#  'H' 'Cl' 'P' 'B' 'H' 'P' 'H' 'B' 'H']

# %% [markdown]
# * Application of SVM algorithm and its performance analysis

# %%
svm=SVC(C=10)
svm.fit(train_x,train_y)
print("Training Score: {:.3f}".format(svm.score(train_x,train_y)))
print("Test score: {:.3f}".format(svm.score(test_x,test_y)))

functions.plot_cnf(svm,test_x,test_y,GENRES)
# Out:
# Training Score: 0.934
# Test score: 0.907
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['H' 'H' 'P' 'M' 'M' 'M' 'Cl' 'B' 'P' 'B' 'P' 'H' 'Cl' 'H' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'H' 'P' 'M' 'M' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'M' 'B' 'P' 'P' 'M' 'Cl' 'H' 'B' 'P' 'Cl' 'H' 'P' 'P' 'B' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'H' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H'
#  'H' 'M' 'P' 'P' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B'
#  'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'H' 'M' 'M' 'Cl' 'P' 'P' 'B' 'H' 'M' 'M' 'Cl'
#  'M' 'B' 'M' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'P' 'H' 'P' 'B' 'Cl' 'M' 'H' 'M'
#  'B' 'H' 'Cl' 'P' 'B' 'H' 'P' 'H' 'B' 'H']
#
# Predicted Test dataset labels:
# ['H' 'H' 'P' 'M' 'H' 'M' 'Cl' 'B' 'P' 'B' 'P' 'P' 'Cl' 'P' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'M' 'H' 'Cl' 'Cl' 'P' 'P' 'M' 'M' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'H' 'H' 'P' 'P' 'M' 'Cl' 'H' 'B' 'P' 'Cl' 'P' 'P' 'P' 'Cl' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'P' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H'
#  'H' 'M' 'P' 'P' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B'
#  'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'B' 'M' 'M' 'Cl' 'P' 'Cl' 'B' 'H' 'M' 'M'
#  'Cl' 'M' 'B' 'M' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'H' 'H' 'P' 'B' 'Cl' 'M' 'H'
#  'M' 'B' 'H' 'Cl' 'P' 'B' 'H' 'P' 'B' 'B' 'H']

# %% [markdown]
# * Application of KNN algorithm and its performance analysis

# %%
neural=MLPClassifier(max_iter=450,random_state=2,hidden_layer_sizes=[45,45])
neural.fit(train_x,train_y)
print("Training Score: {:.3f}".format(neural.score(train_x,train_y)))
print("Test score: {:.3f}".format(neural.score(test_x,test_y)))

functions.plot_cnf(neural,test_x,test_y,GENRES)
# Out:
# Training Score: 0.997
# Test score: 0.900
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['H' 'H' 'P' 'M' 'M' 'M' 'Cl' 'B' 'P' 'B' 'P' 'H' 'Cl' 'H' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'H' 'P' 'M' 'M' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'M' 'B' 'P' 'P' 'M' 'Cl' 'H' 'B' 'P' 'Cl' 'H' 'P' 'P' 'B' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'H' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H'
#  'H' 'M' 'P' 'P' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B'
#  'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'H' 'M' 'M' 'Cl' 'P' 'P' 'B' 'H' 'M' 'M' 'Cl'
#  'M' 'B' 'M' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'P' 'H' 'P' 'B' 'Cl' 'M' 'H' 'M'
#  'B' 'H' 'Cl' 'P' 'B' 'H' 'P' 'H' 'B' 'H']
#
# Predicted Test dataset labels:
# ['H' 'H' 'P' 'M' 'H' 'M' 'Cl' 'B' 'P' 'B' 'P' 'P' 'Cl' 'H' 'M' 'Cl' 'Cl'
#  'B' 'Cl' 'Cl' 'M' 'Cl' 'Cl' 'M' 'H' 'H' 'P' 'B' 'M' 'B' 'H' 'B' 'P' 'Cl'
#  'B' 'Cl' 'Cl' 'P' 'B' 'H' 'Cl' 'Cl' 'P' 'P' 'M' 'M' 'Cl' 'H' 'Cl' 'H' 'Cl'
#  'H' 'H' 'H' 'P' 'P' 'M' 'Cl' 'P' 'B' 'P' 'Cl' 'P' 'P' 'P' 'Cl' 'M' 'B' 'B'
#  'P' 'P' 'P' 'Cl' 'Cl' 'B' 'P' 'B' 'P' 'B' 'H' 'Cl' 'B' 'B' 'B' 'P' 'P' 'H'
#  'H' 'M' 'P' 'P' 'B' 'P' 'M' 'Cl' 'B' 'P' 'B' 'Cl' 'Cl' 'H' 'Cl' 'M' 'B'
#  'P' 'M' 'Cl' 'P' 'M' 'M' 'H' 'M' 'M' 'M' 'Cl' 'P' 'Cl' 'B' 'P' 'M' 'M'
#  'Cl' 'M' 'B' 'H' 'M' 'H' 'M' 'M' 'H' 'M' 'B' 'H' 'P' 'P' 'B' 'Cl' 'M' 'H'
#  'M' 'B' 'H' 'Cl' 'P' 'B' 'H' 'P' 'H' 'B' 'H']
